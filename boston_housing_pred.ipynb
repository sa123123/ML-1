# %%
import numpy as np
import pandas as pd
import sklearn

# %%
df=pd.read_csv("data//housing.data",delim_whitespace=True,header=None)
col_name=['CRIM','ZN','INDUS','CHAX','NOX','RM','AGE','DIS','RAD','TAX','PATRATIO','B','LSTAT','MEDV']
df.columns=col_name
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAX    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PATRATIO       B  LSTAT  MEDV
# 0      15.3  396.90   4.98  24.0
# 1      17.8  396.90   9.14  21.6
# 2      17.8  392.83   4.03  34.7
# 3      18.7  394.63   2.94  33.4
# 4      18.7  396.90   5.33  36.2

# %% [markdown]
# # EDA(EXPLORATORY DATA ANALYSIS)

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAX         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX    PATRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df,height=1.5);
plt.show()

# %%
col_study=['CRIM','RM']

# %%
sns.pairplot(df[col_study],height=3)
plt.show()

# %% [markdown]
# # another example

# %%
d=pd.read_csv("data//car.data",header=None)
d.head()
# Out:
#        0      1  2  3      4     5      6
# 0  vhigh  vhigh  2  2  small   low  unacc
# 1  vhigh  vhigh  2  2  small   med  unacc
# 2  vhigh  vhigh  2  2  small  high  unacc
# 3  vhigh  vhigh  2  2    med   low  unacc
# 4  vhigh  vhigh  2  2    med   med  unacc

# %% [markdown]
# # CORRELATION ANALYSIS AND FEATURE SELECTION

# %%
df.corr()
# Out:
#               CRIM        ZN     INDUS      CHAX       NOX        RM  \
# CRIM      1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN       -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS     0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAX     -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX       0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM       -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE       0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS      -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD       0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX       0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PATRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B        -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# LSTAT     0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808
# ...

# %%
pd.options.display.float_format='{:,.3f}'.format

# %%
df.corr()
# Out:
#            CRIM     ZN  INDUS   CHAX    NOX     RM    AGE    DIS    RAD  \
# CRIM      1.000 -0.200  0.407 -0.056  0.421 -0.219  0.353 -0.380  0.626
# ZN       -0.200  1.000 -0.534 -0.043 -0.517  0.312 -0.570  0.664 -0.312
# INDUS     0.407 -0.534  1.000  0.063  0.764 -0.392  0.645 -0.708  0.595
# CHAX     -0.056 -0.043  0.063  1.000  0.091  0.091  0.087 -0.099 -0.007
# NOX       0.421 -0.517  0.764  0.091  1.000 -0.302  0.731 -0.769  0.611
# RM       -0.219  0.312 -0.392  0.091 -0.302  1.000 -0.240  0.205 -0.210
# AGE       0.353 -0.570  0.645  0.087  0.731 -0.240  1.000 -0.748  0.456
# DIS      -0.380  0.664 -0.708 -0.099 -0.769  0.205 -0.748  1.000 -0.495
# RAD       0.626 -0.312  0.595 -0.007  0.611 -0.210  0.456 -0.495  1.000
# TAX       0.583 -0.315  0.721 -0.036  0.668 -0.292  0.506 -0.534  0.910
# PATRATIO  0.290 -0.392  0.383 -0.122  0.189 -0.356  0.262 -0.232  0.465
# B        -0.385  0.176 -0.357  0.049 -0.380  0.128 -0.274  0.292 -0.444
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# AS UPPER WE CAN SEE THAT MORE THE BLACKER,MORE WILL BE THE INVERSE CORRELATION BETWEEN MEDV AND LSTAT AND RM(HORIZONTALLY)

# %% [markdown]
# NOW FOR ONLY SOME COLUMNS

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df[['CRIM','ZN','INDUS','CHAX','MEDV']].corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df[['NOX','RM','MEDV']].corr(),annot=True)
plt.show()
